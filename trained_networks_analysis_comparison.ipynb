# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiopaniego/BehaviorStudio-experiments/blob/main/trained_networks_analysis_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, I explore the previous trained networks to analyse and compare then.
#
# * MAE | MSE for the different networks.
# * Activations of CNN layers to undestand what they are actually learning?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## General Stats

# %%
# !ls "/content/drive/My Drive"

'''
 20210215-180738_deepest_lstm_tinypilotnet_model_sequence.csv
 20210215-180738_deepest_lstm_tinypilotnet_model_sequence.h5

 20210216-084753_tinypilotnet_lstm_model_sequence.csv
 20210216-084753_tinypilotnet_lstm_model_sequence.h5

 20210216-091101_tinypilotnet_model_sequence.csv
 20210216-091101_tinypilotnet_model_sequence.h5

 20210216-095459_pilotnet_model_model_sequence.csv
 20210216-095459_pilotnet_model_model_sequence.h5
'''

import pandas
import matplotlib.pyplot as plt
import numpy as np

deepest_lstm_csv = pandas.read_csv('/content/drive/My Drive/20210215-180738_deepest_lstm_tinypilotnet_model_sequence.csv')
fig, ax = plt.subplots()
deepest_lstm_csv.loss.plot(ax=ax, style='b-')
deepest_lstm_csv.mae.plot(ax=ax, style='r-')
deepest_lstm_csv.mse.plot(ax=ax, style='g-')
deepest_lstm_csv.val_loss.plot(ax=ax, style='c-')
deepest_lstm_csv.val_mae.plot(ax=ax, style='m-')
deepest_lstm_csv.val_mse.plot(ax=ax, style='k-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3], ax.get_lines()[4], ax.get_lines()[5]],\
           ['loss','mae','mse','val_loss', 'val_mae', 'val_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Deepest Tinypilotnet LSTM training stats')
plt.xlabel('Epoch')
plt.ylabel('Error')

tinypilotnet_lstm_csv = pandas.read_csv('/content/drive/My Drive/20210216-084753_tinypilotnet_lstm_model_sequence.csv')
fig, ax = plt.subplots()
tinypilotnet_lstm_csv.loss.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.mae.plot(ax=ax, style='r-')
tinypilotnet_lstm_csv.mse.plot(ax=ax, style='g-')
tinypilotnet_lstm_csv.val_loss.plot(ax=ax, style='c-')
tinypilotnet_lstm_csv.val_mae.plot(ax=ax, style='m-')
tinypilotnet_lstm_csv.val_mse.plot(ax=ax, style='k-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3], ax.get_lines()[4], ax.get_lines()[5]],\
           ['loss','mae','mse','val_loss', 'val_mae', 'val_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Tinypilotnet LSTM training stats')
plt.xlabel('Epoch')
plt.ylabel('Error')

tinypilotnet_csv = pandas.read_csv('/content/drive/My Drive/20210216-091101_tinypilotnet_model_sequence.csv')
fig, ax = plt.subplots()
tinypilotnet_csv.loss.plot(ax=ax, style='b-')
tinypilotnet_csv.mae.plot(ax=ax, style='r-')
tinypilotnet_csv.mse.plot(ax=ax, style='g-')
tinypilotnet_csv.val_loss.plot(ax=ax, style='c-')
tinypilotnet_csv.val_mae.plot(ax=ax, style='m-')
tinypilotnet_csv.val_mse.plot(ax=ax, style='k-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3], ax.get_lines()[4], ax.get_lines()[5]],\
           ['loss','mae','mse','val_loss', 'val_mae', 'val_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Tinypilotnet training stats')
plt.xlabel('Epoch')
plt.ylabel('Error')

pilotnet_csv = pandas.read_csv('/content/drive/My Drive/20210216-095459_pilotnet_model_model_sequence.csv')
fig, ax = plt.subplots()
pilotnet_csv.loss.plot(ax=ax, style='b-')
pilotnet_csv.mae.plot(ax=ax, style='r-')
pilotnet_csv.mse.plot(ax=ax, style='g-')
pilotnet_csv.val_loss.plot(ax=ax, style='c-')
pilotnet_csv.val_mae.plot(ax=ax, style='m-')
pilotnet_csv.val_mse.plot(ax=ax, style='k-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3], ax.get_lines()[4], ax.get_lines()[5]],\
           ['loss','mae','mse','val_loss', 'val_mae', 'val_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Pilotnet training stats')
plt.xlabel('Epoch')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# # Error stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.loss.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.loss.plot(ax=ax, style='r-')
tinypilotnet_csv.loss.plot(ax=ax, style='g-')
pilotnet_csv.loss.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_loss','tinypilotnet_lstm_loss','tinypilotnet_loss','pilotnet_loss'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# # MAE stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.mae.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.mae.plot(ax=ax, style='r-')
tinypilotnet_csv.mae.plot(ax=ax, style='g-')
pilotnet_csv.mae.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_mae','tinypilotnet_lstm_mae','tinypilotnet_mae','pilotnet_mae'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
# Out:
# Text(0, 0.5, 'MAE')

# %% [markdown]
# # MSE stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.mse.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.mse.plot(ax=ax, style='r-')
tinypilotnet_csv.mse.plot(ax=ax, style='g-')
pilotnet_csv.mse.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_mse','tinypilotnet_lstm_mse','tinypilotnet_mse','pilotnet_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training mse')
plt.xlabel('Epoch')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# # Val loss stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.val_loss.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.val_loss.plot(ax=ax, style='r-')
tinypilotnet_csv.val_loss.plot(ax=ax, style='g-')
pilotnet_csv.val_loss.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_val_loss','tinypilotnet_lstm_val_loss','tinypilotnet_val_loss','pilotnet_val_loss'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training mse')
plt.xlabel('Epoch')
plt.ylabel('val_loss')
# Out:
# Text(0, 0.5, 'val_loss')

# %% [markdown]
# # Val mae stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.val_mae.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.val_mae.plot(ax=ax, style='r-')
tinypilotnet_csv.val_mae.plot(ax=ax, style='g-')
pilotnet_csv.val_mae.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_val_mae','tinypilotnet_lstm_val_mae','tinypilotnet_val_mae','pilotnet_val_mae'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training val_mae')
plt.xlabel('Epoch')
plt.ylabel('Val MAE')
# Out:
# Text(0, 0.5, 'Val MAE')

# %% [markdown]
# # Val mse stats

# %%
fig, ax = plt.subplots()
deepest_lstm_csv.val_mse.plot(ax=ax, style='b-')
tinypilotnet_lstm_csv.val_mse.plot(ax=ax, style='r-')
tinypilotnet_csv.val_mse.plot(ax=ax, style='g-')
pilotnet_csv.val_mse.plot(ax=ax, style='c-')

ax.legend([ax.get_lines()[0], ax.get_lines()[1], ax.get_lines()[2], ax.get_lines()[3]],\
           ['deepest_lstm_val_mse','tinypilotnet_lstm_val_mse','tinypilotnet_val_mse','pilotnet_val_mse'], bbox_to_anchor=(1.5, 0.5))
plt.title('Training val_mse')
plt.xlabel('Epoch')
plt.ylabel('VAL MSE')
# Out:
# Text(0, 0.5, 'VAL MSE')

# %% [markdown]
# # Show parameters for each trained architecture

# %%
'''
 20210215-180738_deepest_lstm_tinypilotnet_model_sequence.csv
 20210215-180738_deepest_lstm_tinypilotnet_model_sequence.h5

 20210216-084753_tinypilotnet_lstm_model_sequence.csv
 20210216-084753_tinypilotnet_lstm_model_sequence.h5

 20210216-091101_tinypilotnet_model_sequence.csv
 20210216-091101_tinypilotnet_model_sequence.h5

 20210216-095459_pilotnet_model_model_sequence.csv
 20210216-095459_pilotnet_model_model_sequence.h5
'''

from tensorflow import keras
print('--- DEEPEST LSTM TINYPILOTNET MODEL ---')
deepest_lstm_tinypilotnet = keras.models.load_model('/content/drive/My Drive/20210215-180738_deepest_lstm_tinypilotnet_model_sequence.h5')
deepest_lstm_tinypilotnet.summary()
print('----------------------------------------')

print('--- LSTM TINYPILOTNET MODEL ---')
lstm_tinypilotnet = keras.models.load_model('/content/drive/My Drive/20210216-084753_tinypilotnet_lstm_model_sequence.h5')
lstm_tinypilotnet.summary()
print('----------------------------------------')

print('---  TINYPILOTNET MODEL ---')
tinypilotnet = keras.models.load_model('/content/drive/My Drive/20210216-091101_tinypilotnet_model_sequence.h5')
tinypilotnet.summary()
print('----------------------------------------')

print('---  PILOTNET MODEL ---')
pilotnet = keras.models.load_model('/content/drive/My Drive/20210216-095459_pilotnet_model_model_sequence.h5')
pilotnet.summary()
print('----------------------------------------')

print('---PARAMS NUMBER---')
print('deepest_lstm_tinypilotnet -> ' + str(deepest_lstm_tinypilotnet.count_params()))
print('lstm_tinypilotnet -> ' + str(lstm_tinypilotnet.count_params()))
print('tinypilotnet -> ' + str(tinypilotnet.count_params()))
print('pilotnet -> ' + str(pilotnet.count_params()))
# Out:
# --- DEEPEST LSTM TINYPILOTNET MODEL ---
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# batch_normalization (BatchNo (None, 60, 160, 3)        12
# _________________________________________________________________
# conv2d (Conv2D)              (None, 29, 79, 8)         224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 39, 8)         584
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 19, 8)          584
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 19, 8)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 6, 19, 8)       0
# _________________________________________________________________
# ...

# %% [markdown]
# # Test different networks over some images to understand the output

# %%
# !unzip "/content/drive/My Drive/curves_only.zip"
# !unzip "/content/drive/My Drive/complete_dataset.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: complete_dataset/Images/4655.png
#   inflating: complete_dataset/Images/13432.png
#   inflating: complete_dataset/Images/13393.png
#   inflating: complete_dataset/Images/14645.png
#   inflating: complete_dataset/Images/16896.png
#   inflating: complete_dataset/Images/4638.png
#   inflating: complete_dataset/Images/12695.png
#   inflating: complete_dataset/Images/13074.png
#   inflating: complete_dataset/Images/16020.png
#   inflating: complete_dataset/Images/15454.png
#   inflating: complete_dataset/Images/690.png
#   inflating: complete_dataset/Images/8168.png
#   inflating: complete_dataset/Images/4244.png
#   inflating: complete_dataset/Images/16078.png
#   inflating: complete_dataset/Images/6062.png
#   inflating: complete_dataset/Images/7468.png
#   inflating: complete_dataset/Images/1326.png
#   inflating: complete_dataset/Images/2106.png
#   inflating: complete_dataset/Images/585.png
# ...

# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt


def load_data(folder):
    name_folder = '/content/' + folder + '/Images/'
    list_images = glob.glob(name_folder + '*')
    print(list_images)
    images = sorted(list_images, key=lambda x: int(x.split('/')[4].split('.png')[0]))
    name_file = '/content/' + folder + '/data.json'
    file = open(name_file, 'r')
    data = file.read()
    file.close()
    return images, data

def get_images(list_images, type_image, array_imgs):
    # Read the images
    for name in list_images:
        img = cv2.imread(name)
        if type_image == 'cropped':
            img = img[240:480, 0:640]
        img = cv2.resize(img, (int(img.shape[1] / 4), int(img.shape[0] / 4)))
        array_imgs.append(img)

    return array_imgs

def parse_json(data, array):
    # Process json
    data_parse = data.split('}')[:-1]
    for d in data_parse:
        v = d.split('"v": ')[1]
        d_parse = d.split(', "v":')[0]
        w = d_parse.split(('"w": '))[1]
        array.append((float(v), float(w)))

    return array

def preprocess_data(array, imgs):
    # Data augmentation
    # Take the image and just flip it and negate the measurement
    flip_imgs = []
    array_flip = []
    for i in range(len(array)):
        flip_imgs.append(cv2.flip(imgs[i], 1))
        array_flip.append((array[i][0], -array[i][1]))
    new_array = array + array_flip
    new_array_imgs = imgs + flip_imgs
    return new_array, new_array_imgs


# Load data
images, data = load_data('complete_dataset')
images_curve, data_curve = load_data('curves_only')

# CHANGE type_image
type_image = 'cropped'
#type_image='normal'

# Preprocess images
array_imgs = []
array_imgs = get_images(images, type_image, array_imgs)
array_imgs = get_images(images_curve, type_image, array_imgs)
# Preprocess json
array_annotations = []
array_annotations = parse_json(data, array_annotations)
array_annotations = parse_json(data_curve, array_annotations)


if type_image == 'cropped':
    img_shape = (65, 160, 3)
else:
    img_shape = (120, 160, 3)


# Adapt the data
array_annotations, array_imgs = preprocess_data(array_annotations, array_imgs)
# x = x[:]


# START NORMALIZE DATA
array_annotations_v = []
array_annotations_w = []

for annotation in array_annotations:
  array_annotations_v.append(annotation[0])
  array_annotations_w.append(annotation[1])
  
array_annotations_v = np.stack(array_annotations_v, axis=0)
array_annotations_v = array_annotations_v.reshape(-1, 1)

array_annotations_w = np.stack(array_annotations_w, axis=0)
array_annotations_w = array_annotations_w.reshape(-1, 1)

def normalize(x):
    x = np.asarray(x)
    return (x - x.min()) / (np.ptp(x))
normalized_X = normalize(array_annotations_v)
# normalized_Y = normalize(array_annotations_w)
old_min = array_annotations_w.min()
old_range = array_annotations_w.max() - old_min

new_min = -1
new_range = 2
normalized_Y = [(n - old_min) / old_range * new_range + new_min for n in array_annotations_w]
normalized_Y = np.array(normalized_Y)

normalized_annotations = []
for i in range(0, len(normalized_X)):
  normalized_annotations.append([normalized_X.item(i), normalized_Y.item(i)])

normalized_annotations = np.stack(normalized_annotations, axis=0)
array_annotations = normalized_annotations
# END NORMALIZE DATA

split_test_train_value = 0.30
#images_train, images_validation, annotations_train, annotations_validation = train_test_split(array_imgs, array_annotations, test_size=0.30, random_state=42)
# FOR LSTMs -> suffle=False because the order of images is relevant
images_train, images_validation, annotations_train, annotations_validation = train_test_split(array_imgs, array_annotations, test_size=split_test_train_value, random_state=42, shuffle=False)
#images_train, images_validation, annotations_train, annotations_validation = train_test_split(array_2_images, array_annotations, test_size=0.30, random_state=42)

# Adapt the data
images_train = np.stack(images_train, axis=0)
annotations_train = np.stack(annotations_train, axis=0)
images_validation = np.stack(images_validation, axis=0)
annotations_validation = np.stack(annotations_validation, axis=0)

print(annotations_train[0])
print(annotations_train.shape)

#video = np.stack(array_imgs, axis=0)
print(images_train.shape)
print(images_validation.shape)
# Out:
# ['/content/complete_dataset/Images/6995.png', '/content/complete_dataset/Images/10192.png', '/content/complete_dataset/Images/3177.png', '/content/complete_dataset/Images/14381.png', '/content/complete_dataset/Images/10433.png', '/content/complete_dataset/Images/3343.png', '/content/complete_dataset/Images/3952.png', '/content/complete_dataset/Images/7704.png', '/content/complete_dataset/Images/13061.png', '/content/complete_dataset/Images/9000.png', '/content/complete_dataset/Images/13809.png', '/content/complete_dataset/Images/4586.png', '/content/complete_dataset/Images/3133.png', '/content/complete_dataset/Images/10205.png', '/content/complete_dataset/Images/16641.png', '/content/complete_dataset/Images/11982.png', '/content/complete_dataset/Images/8263.png', '/content/complete_dataset/Images/4447.png', '/content/complete_dataset/Images/14432.png', '/content/complete_dataset/Images/15080.png', '/content/complete_dataset/Images/12073.png', '/content/complete_dataset/Images/14389.p
# ...

# %%
import cv2
import matplotlib.pyplot as plt


regression_v = keras.models.load_model('/content/drive/My Drive/model_pilotnet_cropped_300_v.h5')
regression_w = keras.models.load_model('/content/drive/My Drive/model_pilotnet_cropped_300_w.h5')


img = images_train[0]
imgplot = plt.imshow(img)
plt.show()

images = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
result_tinypilotnet = tinypilotnet.predict(images)
result_pilotnet = pilotnet.predict(images)
result_regression_v = regression_v.predict(images)
result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations_train[0]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations_train[0][0]*13) + ' ' + str(annotations_train[0][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images_train[5000]
imgplot = plt.imshow(img)
plt.show()

images = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
result_tinypilotnet = tinypilotnet.predict(images)
result_pilotnet = pilotnet.predict(images)
result_regression_v = regression_v.predict(images)
result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations_train[5000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations_train[5000][0]*13) + ' ' + str(annotations_train[5000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))


img = images_train[10000]
imgplot = plt.imshow(img)
plt.show()

images = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
result_tinypilotnet = tinypilotnet.predict(images)
result_pilotnet = pilotnet.predict(images)
result_regression_v = regression_v.predict(images)
result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations_train[10000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations_train[10000][0]*13) + ' ' + str(annotations_train[10000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images_train[15000]
imgplot = plt.imshow(img)
plt.show()

images = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
result_tinypilotnet = tinypilotnet.predict(images)
result_pilotnet = pilotnet.predict(images)
result_regression_v = regression_v.predict(images)
result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations_train[15000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations_train[15000][0]*13) + ' ' + str(annotations_train[15000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))
# Out:
# ground truth -> [1.         0.00947395]
# result_deepest_lstm_tinypilotnet -> [[0.89555544 0.03721421]]
# result_lstm_tinypilotnet -> [[0.93135434 0.03932231]]
# result_tinypilotnet -> [[1.0248655  0.00953744]]
# result_pilotnet -> [[1.058208   0.00909934]]
# ground truth 2 -> 13.0 0.028421863960434335
# result_regression_v -> [[12.923797]]
# result_regression_w -> [[0.02908546]]
# result_deepest_lstm_tinypilotnet -> 11.642220675945282 0.4837847575545311
# result_lstm_tinypilotnet -> 12.10760647058487 0.5111900195479393
# result_tinypilotnet -> 13.323251605033875 0.12398672942072153
# result_pilotnet -> 13.756703853607178 0.11829143296927214
# ground truth -> [0.70588235 0.10212602]
# result_deepest_lstm_tinypilotnet -> [[0.64484596 0.09847517]]
# result_lstm_tinypilotnet -> [[0.70746404 0.06548508]]
# result_tinypilotnet -> [[0.6817362  0.12503184]]
# result_pilotnet -> [[0.7042747  0.10098293]]
# ground truth 2 -> 9.176470588235295 0.3063780589633247
# ...

# %%
from tensorflow.keras.losses import MSE, MAE

#img = images_validation[10000]
#imgplot = plt.imshow(img)
#plt.show()

#images = np.stack([img], axis=0)
images = images_validation
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations_validation[0][0]*13) + ' ' + str(annotations_validation[0][1]*3))
print('prediction -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations_validation[0], result_deepest_lstm_tinypilotnet[0])
print(loss)
loss = MAE(annotations_validation[0], result_deepest_lstm_tinypilotnet[0])
print(loss)
loss = MSE(annotations_validation, result_deepest_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_deepest_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))

print()
print()

result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations_validation[0][0]*13) + ' ' + str(annotations_validation[0][1]*3))
print('prediction -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations_validation[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MAE(annotations_validation[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MSE(annotations_validation, result_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()


result_tinypilotnet = tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations_validation[0][0]*13) + ' ' + str(annotations_validation[0][1]*3))
print('prediction -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*3))
loss = MSE(annotations_validation[0], result_tinypilotnet[0])
print(loss)
loss = MAE(annotations_validation[0], result_tinypilotnet[0])
print(loss)
loss = MSE(annotations_validation, result_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_pilotnet = pilotnet.predict(images)
print('ground truth -> ' + str(annotations_validation[0][0]*13) + ' ' + str(annotations_validation[0][1]*3))
print('prediction -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*3))
loss = MSE(annotations_validation[0], result_pilotnet[0])
print(loss)
loss = MAE(annotations_validation[0], result_pilotnet[0])
print(loss)
loss = MSE(annotations_validation, result_pilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_pilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_regression_v = regression_v.predict(images)
print('ground truth -> ' + str(annotations_validation[0][0]*13))
print('prediction -> ' + str(result_regression_v))
loss = MSE(annotations_validation[0][0]*13, result_regression_v)
print(loss)
loss = MAE(annotations_validation[0][0]*13, result_regression_v)
print(loss)
loss = MSE(annotations_validation, result_regression_v)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_regression_v)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations_validation[0][1]*3))
print('prediction -> ' + str(result_regression_w))
loss = MSE(annotations_validation[0][1]*3, result_regression_w)
print(loss)
loss = MAE(annotations_validation[0][1]*3, result_regression_w)
print(loss)
loss = MSE(annotations_validation, result_regression_w)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations_validation, result_regression_w)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()
'''
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images_validation)
print(result_lstm_tinypilotnet[0])
result_tinypilotnet = tinypilotnet.predict(images_validation)
print(result_tinypilotnet[0])
result_pilotnet = pilotnet.predict(images_validation)
print(result_pilotnet[0])
result_regression_v = regression_v.predict(images_validation)
print(result_regression_v[0])
result_regression_w = regression_w.predict(images_validation)
print(result_regression_w[0])
'''
# Out:
# ground truth -> 5.352941176470588 -0.2597469330079004
# prediction -> 6.079052448272705 -0.2867417111992836
# tf.Tensor(0.0016003585, shape=(), dtype=float32)
# tf.Tensor(0.032426484, shape=(), dtype=float32)
# tf.Tensor([0.00160036 0.00126803 0.00077922 ... 0.00409698 0.00903938 0.00958129], shape=(13566,), dtype=float32)
# MSE -> 0.013019617
# tf.Tensor([0.03242648 0.03511459 0.02666371 ... 0.05309227 0.07625861 0.07918188], shape=(13566,), dtype=float32)
# MAE -> 0.07039029
#
#
# ground truth -> 5.352941176470588 -0.2597469330079004
# prediction -> 5.8126004338264465 -0.1993086040019989
# tf.Tensor(0.00082804105, shape=(), dtype=float32)
# tf.Tensor(0.027752254, shape=(), dtype=float32)
# tf.Tensor([0.00082804 0.00192261 0.00170821 ... 0.00294091 0.00381433 0.00673002], shape=(13566,), dtype=float32)
# MSE -> 0.014070004
# tf.Tensor([0.02775225 0.0420199  0.04077231 ... 0.05273075 0.05409342 0.0619873 ], shape=(13566,), dtype=float32)
# MAE -> 0.0760204
#
#
# ...

# %%
# !ls "/content/drive/My Drive"
# !unzip "/content/drive/My Drive/many_curves_dataset.zip"
# Out:
#  20210215-134322_model_lstm_sequence_test_cp.h5
#  20210215-134322_model_lstm_sequence_test.csv
#  20210215-134625_model_lstm_sequence_test_cp.h5
#  20210215-134625_model_lstm_sequence_test.csv
#  20210215-134625_model_lstm_sequence_test.h5
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence_cp.h5
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence.csv
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence.h5
#  20210216-084753_tinypilotnet_lstm_model_sequence_cp.h5
#  20210216-084753_tinypilotnet_lstm_model_sequence.csv
#  20210216-084753_tinypilotnet_lstm_model_sequence.h5
#  20210216-091101_tinypilotnet_model_sequence_cp.h5
#  20210216-091101_tinypilotnet_model_sequence.csv
#  20210216-091101_tinypilotnet_model_sequence.h5
#  20210216-095459_pilotnet_model_model_sequence_cp.h5
#  20210216-095459_pilotnet_model_model_sequence.csv
#  20210216-095459_pilotnet_model_model_sequence.h5
#  AI-exam.zip
#  certificados-horas-formativas-doctorado
# 'Colab Notebooks'
# ...

# %%
import json
def load_data(folder):
    name_folder = '/content/' + folder + '/'
    list_images = glob.glob(name_folder + '*.png')
    print(list_images)
    images = sorted(list_images, key=lambda x: int(x.split('/')[3].split('.png')[0]))
    name_file = '/content/' + folder + '/data.json'
    json_file = open(name_file, 'r')
    data = json.load(json_file)
    json_file.close()
    return images, data

def get_images(list_images, type_image, array_imgs):
    # Read the images
    for name in list_images:
        img = cv2.imread(name)
        if type_image == 'cropped':
            img = img[240:480, 0:640]
        img = cv2.resize(img, (int(img.shape[1] / 4), int(img.shape[0] / 4)))
        array_imgs.append(img)

    return array_imgs

def parse_json(data, array):
    # Process json
    for key, value in data.items():
      v = data[key]['v']
      w = data[key]['w']
      array.append((float(v), float(w)))

    return array

def preprocess_data(array, imgs):
    # Data augmentation
    # Take the image and just flip it and negate the measurement
    flip_imgs = []
    array_flip = []
    for i in range(len(array)):
        flip_imgs.append(cv2.flip(imgs[i], 1))
        array_flip.append((array[i][0], -array[i][1]))
    new_array = array + array_flip
    new_array_imgs = imgs + flip_imgs
    return new_array, new_array_imgs


# Load data
images, data = load_data('many_curves_dataset')

# CHANGE type_image
type_image = 'cropped'
#type_image='normal'

# Preprocess images
array_imgs = []
array_imgs = get_images(images, type_image, array_imgs)
# Preprocess json
array_annotations = []
array_annotations = parse_json(data, array_annotations)


if type_image == 'cropped':
    img_shape = (65, 160, 3)
else:
    img_shape = (120, 160, 3)


# Adapt the data
array_annotations, array_imgs = preprocess_data(array_annotations, array_imgs)
# x = x[:]


# START NORMALIZE DATA
array_annotations_v = []
array_annotations_w = []

for annotation in array_annotations:
  array_annotations_v.append(annotation[0])
  array_annotations_w.append(annotation[1])
  
array_annotations_v = np.stack(array_annotations_v, axis=0)
array_annotations_v = array_annotations_v.reshape(-1, 1)

array_annotations_w = np.stack(array_annotations_w, axis=0)
array_annotations_w = array_annotations_w.reshape(-1, 1)

def normalize(x):
    x = np.asarray(x)
    return (x - x.min()) / (np.ptp(x))
normalized_X = normalize(array_annotations_v)
# normalized_Y = normalize(array_annotations_w)
old_min = array_annotations_w.min()
old_range = array_annotations_w.max() - old_min

new_min = -1
new_range = 2
normalized_Y = [(n - old_min) / old_range * new_range + new_min for n in array_annotations_w]
normalized_Y = np.array(normalized_Y)

normalized_annotations = []
for i in range(0, len(normalized_X)):
  normalized_annotations.append([normalized_X.item(i), normalized_Y.item(i)])

normalized_annotations = np.stack(normalized_annotations, axis=0)
array_annotations = normalized_annotations
# END NORMALIZE DATA


# Adapt the data
images = np.stack(array_imgs, axis=0)
annotations = np.stack(array_annotations, axis=0)

print(images.shape)
print(annotations.shape)
# Out:
# ['/content/many_curves_dataset/893.png', '/content/many_curves_dataset/1287.png', '/content/many_curves_dataset/1132.png', '/content/many_curves_dataset/980.png', '/content/many_curves_dataset/1638.png', '/content/many_curves_dataset/266.png', '/content/many_curves_dataset/625.png', '/content/many_curves_dataset/2244.png', '/content/many_curves_dataset/1902.png', '/content/many_curves_dataset/234.png', '/content/many_curves_dataset/1450.png', '/content/many_curves_dataset/1361.png', '/content/many_curves_dataset/1649.png', '/content/many_curves_dataset/219.png', '/content/many_curves_dataset/1124.png', '/content/many_curves_dataset/247.png', '/content/many_curves_dataset/2072.png', '/content/many_curves_dataset/1394.png', '/content/many_curves_dataset/1295.png', '/content/many_curves_dataset/67.png', '/content/many_curves_dataset/2059.png', '/content/many_curves_dataset/2344.png', '/content/many_curves_dataset/1613.png', '/content/many_curves_dataset/372.png', '/content/many_curves_d
# ...

# %%
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_deepest_lstm_tinypilotnet[0])
print('MSE 0 -> ' + str(loss))
loss = MAE(annotations[0], result_deepest_lstm_tinypilotnet[0])
print('MAE 0 -> ' + str(loss))
loss = MSE(annotations, result_deepest_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_deepest_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))

print()
print()

result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MAE(annotations[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MSE(annotations, result_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()


result_tinypilotnet = tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_tinypilotnet[0])
print(loss)
loss = MAE(annotations[0], result_tinypilotnet[0])
print(loss)
loss = MSE(annotations, result_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_pilotnet = pilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*3))
loss = MSE(annotations[0], result_pilotnet[0])
print(loss)
loss = MAE(annotations[0], result_pilotnet[0])
print(loss)
loss = MSE(annotations, result_pilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_pilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()
'''
result_regression_v = regression_v.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13))
print('prediction -> ' + str(result_regression_v))
loss = MSE(annotations[0][0]*13, result_regression_v)
print(loss)
loss = MAE(annotations[0][0]*13, result_regression_v)
print(loss)
loss = MSE(annotations, result_regression_v)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_regression_v)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_regression_w))
loss = MSE(annotations[0][1]*3, result_regression_w)
print(loss)
loss = MAE(annotations[0][1]*3, result_regression_w)
print(loss)
loss = MSE(annotations, result_regression_w)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_regression_w)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()
'''
# Out:
# ground truth -> 5.352941176470588 0.7977121512781604
# prediction -> 5.905397713184357 0.1147884652018547
# MSE 0 -> tf.Tensor(0.026813246, shape=(), dtype=float32)
# MAE 0 -> tf.Tensor(0.13506894, shape=(), dtype=float32)
# tf.Tensor([0.02681325 0.02337495 0.02342953 ... 0.01176758 0.01242786 0.01338191], shape=(5526,), dtype=float32)
# MSE -> 0.027905028
# tf.Tensor([0.13506894 0.12724824 0.1280665  ... 0.10839546 0.11144294 0.11501184], shape=(5526,), dtype=float32)
# MAE -> 0.13078406
#
#
# ground truth -> 5.352941176470588 0.7977121512781604
# prediction -> 5.899994224309921 -0.04988788068294525
# tf.Tensor(0.040797953, shape=(), dtype=float32)
# tf.Tensor(0.16230717, shape=(), dtype=float32)
# tf.Tensor([0.04079795 0.03650106 0.03669485 ... 0.03879925 0.02847592 0.03728188], shape=(5526,), dtype=float32)
# MSE -> 0.042269647
# tf.Tensor([0.16230717 0.15448648 0.1536638  ... 0.17772652 0.13831232 0.17755578], shape=(5526,), dtype=float32)
# MAE -> 0.14903374
#
#
# ...

# %%
img = images[0]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[0]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images[1000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[1000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[1000][0]*13) + ' ' + str(annotations[1000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))


img = images[2000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[2000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[2000][0]*13) + ' ' + str(annotations[2000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images[3000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[3000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[3000][0]*13) + ' ' + str(annotations[3000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))
# Out:
# ground truth -> [0.41176471 0.26590405]
# result_deepest_lstm_tinypilotnet -> [[0.45426112 0.03826266]]
# result_lstm_tinypilotnet -> [[ 0.45384583 -0.01662938]]
# result_tinypilotnet -> [[0.80271995 0.02279008]]
# result_pilotnet -> [[0.45546496 0.08105624]]
# ground truth 2 -> 5.352941176470588 0.7977121512781604
# result_regression_v -> [[5.3704243]]
# result_regression_w -> [[0.2953402]]
# result_deepest_lstm_tinypilotnet -> 5.905394613742828 0.49741455167531967
# result_lstm_tinypilotnet -> 5.899995774030685 -0.21618197858333588
# result_tinypilotnet -> 10.435359358787537 0.29627101495862007
# result_pilotnet -> 5.9210444688797 1.053731083869934
# ground truth -> [ 0.41176471 -0.12312361]
# result_deepest_lstm_tinypilotnet -> [[ 0.5929584  -0.02200509]]
# result_lstm_tinypilotnet -> [[ 0.3500224  -0.01542435]]
# result_tinypilotnet -> [[0.5076521  0.00731471]]
# result_pilotnet -> [[0.51795626 0.00969855]]
# ground truth 2 -> 5.352941176470588 -0.36937084160149425
# ...

# %%
# !ls "/content/drive/My Drive"
# !unzip "/content/drive/My Drive/simple_circuit_dataset.zip"
# Out:
#  20210215-134322_model_lstm_sequence_test_cp.h5
#  20210215-134322_model_lstm_sequence_test.csv
#  20210215-134625_model_lstm_sequence_test_cp.h5
#  20210215-134625_model_lstm_sequence_test.csv
#  20210215-134625_model_lstm_sequence_test.h5
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence_cp.h5
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence.csv
#  20210215-180738_deepest_lstm_tinypilotnet_model_sequence.h5
#  20210216-084753_tinypilotnet_lstm_model_sequence_cp.h5
#  20210216-084753_tinypilotnet_lstm_model_sequence.csv
#  20210216-084753_tinypilotnet_lstm_model_sequence.h5
#  20210216-091101_tinypilotnet_model_sequence_cp.h5
#  20210216-091101_tinypilotnet_model_sequence.csv
#  20210216-091101_tinypilotnet_model_sequence.h5
#  20210216-095459_pilotnet_model_model_sequence_cp.h5
#  20210216-095459_pilotnet_model_model_sequence.csv
#  20210216-095459_pilotnet_model_model_sequence.h5
#  AI-exam.zip
#  certificados-horas-formativas-doctorado
# 'Colab Notebooks'
# ...

# %%
import json
def load_data(folder):
    name_folder = '/content/' + folder + '/'
    list_images = glob.glob(name_folder + '*.png')
    print(list_images)
    images = sorted(list_images, key=lambda x: int(x.split('/')[3].split('.png')[0]))
    name_file = '/content/' + folder + '/data.json'
    json_file = open(name_file, 'r')
    data = json.load(json_file)
    json_file.close()
    return images, data

def get_images(list_images, type_image, array_imgs):
    # Read the images
    for name in list_images:
        img = cv2.imread(name)
        if type_image == 'cropped':
            img = img[240:480, 0:640]
        img = cv2.resize(img, (int(img.shape[1] / 4), int(img.shape[0] / 4)))
        array_imgs.append(img)

    return array_imgs

def parse_json(data, array):
    # Process json
    for key, value in data.items():
      v = data[key]['v']
      w = data[key]['w']
      array.append((float(v), float(w)))

    return array

def preprocess_data(array, imgs):
    # Data augmentation
    # Take the image and just flip it and negate the measurement
    flip_imgs = []
    array_flip = []
    for i in range(len(array)):
        flip_imgs.append(cv2.flip(imgs[i], 1))
        array_flip.append((array[i][0], -array[i][1]))
    new_array = array + array_flip
    new_array_imgs = imgs + flip_imgs
    return new_array, new_array_imgs


# Load data
images, data = load_data('simple_circuit_dataset')

# CHANGE type_image
type_image = 'cropped'
#type_image='normal'

# Preprocess images
array_imgs = []
array_imgs = get_images(images, type_image, array_imgs)
# Preprocess json
array_annotations = []
array_annotations = parse_json(data, array_annotations)


if type_image == 'cropped':
    img_shape = (65, 160, 3)
else:
    img_shape = (120, 160, 3)


# Adapt the data
array_annotations, array_imgs = preprocess_data(array_annotations, array_imgs)
# x = x[:]


# START NORMALIZE DATA
array_annotations_v = []
array_annotations_w = []

for annotation in array_annotations:
  array_annotations_v.append(annotation[0])
  array_annotations_w.append(annotation[1])
  
array_annotations_v = np.stack(array_annotations_v, axis=0)
array_annotations_v = array_annotations_v.reshape(-1, 1)

array_annotations_w = np.stack(array_annotations_w, axis=0)
array_annotations_w = array_annotations_w.reshape(-1, 1)

def normalize(x):
    x = np.asarray(x)
    return (x - x.min()) / (np.ptp(x))
normalized_X = normalize(array_annotations_v)
# normalized_Y = normalize(array_annotations_w)
old_min = array_annotations_w.min()
old_range = array_annotations_w.max() - old_min

new_min = -1
new_range = 2
normalized_Y = [(n - old_min) / old_range * new_range + new_min for n in array_annotations_w]
normalized_Y = np.array(normalized_Y)

normalized_annotations = []
for i in range(0, len(normalized_X)):
  normalized_annotations.append([normalized_X.item(i), normalized_Y.item(i)])

normalized_annotations = np.stack(normalized_annotations, axis=0)
array_annotations = normalized_annotations
# END NORMALIZE DATA


# Adapt the data
images = np.stack(array_imgs, axis=0)
annotations = np.stack(array_annotations, axis=0)

print(images.shape)
print(annotations.shape)
# Out:
# ['/content/simple_circuit_dataset/893.png', '/content/simple_circuit_dataset/1287.png', '/content/simple_circuit_dataset/1132.png', '/content/simple_circuit_dataset/980.png', '/content/simple_circuit_dataset/1638.png', '/content/simple_circuit_dataset/266.png', '/content/simple_circuit_dataset/625.png', '/content/simple_circuit_dataset/234.png', '/content/simple_circuit_dataset/1450.png', '/content/simple_circuit_dataset/1361.png', '/content/simple_circuit_dataset/1649.png', '/content/simple_circuit_dataset/219.png', '/content/simple_circuit_dataset/1124.png', '/content/simple_circuit_dataset/247.png', '/content/simple_circuit_dataset/1394.png', '/content/simple_circuit_dataset/1295.png', '/content/simple_circuit_dataset/67.png', '/content/simple_circuit_dataset/1613.png', '/content/simple_circuit_dataset/372.png', '/content/simple_circuit_dataset/459.png', '/content/simple_circuit_dataset/553.png', '/content/simple_circuit_dataset/159.png', '/content/simple_circuit_dataset/515.png',
# ...

# %%
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_deepest_lstm_tinypilotnet[0])
print('MSE 0 -> ' + str(loss))
loss = MAE(annotations[0], result_deepest_lstm_tinypilotnet[0])
print('MAE 0 -> ' + str(loss))
loss = MSE(annotations, result_deepest_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_deepest_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))

print()
print()

result_lstm_tinypilotnet = lstm_tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MAE(annotations[0], result_lstm_tinypilotnet[0])
print(loss)
loss = MSE(annotations, result_lstm_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_lstm_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()


result_tinypilotnet = tinypilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*3))
loss = MSE(annotations[0], result_tinypilotnet[0])
print(loss)
loss = MAE(annotations[0], result_tinypilotnet[0])
print(loss)
loss = MSE(annotations, result_tinypilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_tinypilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_pilotnet = pilotnet.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*3))
loss = MSE(annotations[0], result_pilotnet[0])
print(loss)
loss = MAE(annotations[0], result_pilotnet[0])
print(loss)
loss = MSE(annotations, result_pilotnet)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_pilotnet)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()
'''
result_regression_v = regression_v.predict(images)
print('ground truth -> ' + str(annotations[0][0]*13))
print('prediction -> ' + str(result_regression_v))
loss = MSE(annotations[0][0]*13, result_regression_v)
print(loss)
loss = MAE(annotations[0][0]*13, result_regression_v)
print(loss)
loss = MSE(annotations, result_regression_v)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_regression_v)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()

result_regression_w = regression_w.predict(images)
print('ground truth -> ' + str(annotations[0][1]*3))
print('prediction -> ' + str(result_regression_w))
loss = MSE(annotations[0][1]*3, result_regression_w)
print(loss)
loss = MAE(annotations[0][1]*3, result_regression_w)
print(loss)
loss = MSE(annotations, result_regression_w)
print(loss)
print('MSE -> ' + str(np.mean(loss, axis=-1)))
loss = MAE(annotations, result_regression_w)
print(loss)
print('MAE -> ' + str(np.mean(loss, axis=-1)))


print()
print()
'''
# Out:
# ground truth -> 13.0 0.008715991628708952
# prediction -> 6.4820170402526855 -0.05530963093042374
# MSE 0 -> tf.Tensor(0.12592034, shape=(), dtype=float32)
# MAE 0 -> tf.Tensor(0.26136258, shape=(), dtype=float32)
# tf.Tensor([0.12592034 0.12591513 0.14986922 ... 0.03136644 0.03527651 0.03676208], shape=(3550,), dtype=float32)
# MSE -> 0.05967529
# tf.Tensor([0.26136258 0.26123947 0.28549385 ... 0.15286194 0.17780438 0.17870621], shape=(3550,), dtype=float32)
# MAE -> 0.20099033
#
#
# ground truth -> 13.0 0.008715991628708952
# prediction -> 4.67257159948349 0.1273268312215805
# tf.Tensor(0.20594744, shape=(), dtype=float32)
# tf.Tensor(0.34005418, shape=(), dtype=float32)
# tf.Tensor([0.20594744 0.20595722 0.31782272 ... 0.00808317 0.01979846 0.01740617], shape=(3550,), dtype=float32)
# MSE -> 0.07827485
# tf.Tensor([0.34005418 0.3401773  0.40566128 ... 0.08793116 0.13971283 0.13192606], shape=(3550,), dtype=float32)
# MAE -> 0.18370289
#
#
# ...

# %%
img = images[0]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[0]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[0][0]*13) + ' ' + str(annotations[0][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images[1000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[1000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[1000][0]*13) + ' ' + str(annotations[1000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))


img = images[2000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[2000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[2000][0]*13) + ' ' + str(annotations[2000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))

img = images[3000]
imgplot = plt.imshow(img)
plt.show()

img = np.stack([img], axis=0)
result_deepest_lstm_tinypilotnet = deepest_lstm_tinypilotnet.predict(img)
result_lstm_tinypilotnet = lstm_tinypilotnet.predict(img)
result_tinypilotnet = tinypilotnet.predict(img)
result_pilotnet = pilotnet.predict(img)
result_regression_v = regression_v.predict(img)
result_regression_w = regression_w.predict(img)
print('ground truth -> ' + str(annotations[3000]))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet))
print('result_tinypilotnet -> ' + str(result_tinypilotnet))
print('result_pilotnet -> ' + str(result_pilotnet))
print('ground truth 2 -> ' + str(annotations[3000][0]*13) + ' ' + str(annotations[3000][1]*3))
print('result_regression_v -> ' + str(result_regression_v))
print('result_regression_w -> ' + str(result_regression_w))
print('result_deepest_lstm_tinypilotnet -> ' + str(result_deepest_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_deepest_lstm_tinypilotnet[0][1]*13))
print('result_lstm_tinypilotnet -> ' + str(result_lstm_tinypilotnet[0][0]*13) + ' ' + str(result_lstm_tinypilotnet[0][1]*13))
print('result_tinypilotnet -> ' + str(result_tinypilotnet[0][0]*13) + ' ' + str(result_tinypilotnet[0][1]*13))
print('result_pilotnet -> ' + str(result_pilotnet[0][0]*13) + ' ' + str(result_pilotnet[0][1]*13))
# Out:
# ground truth -> [1.         0.00290533]
# result_deepest_lstm_tinypilotnet -> [[ 0.49861673 -0.01843677]]
# result_lstm_tinypilotnet -> [[0.35942852 0.04244233]]
# result_tinypilotnet -> [[0.69387895 0.05026682]]
# result_pilotnet -> [[0.76213205 0.04577737]]
# ground truth 2 -> 13.0 0.008715991628708952
# result_regression_v -> [[5.001105]]
# result_regression_w -> [[-0.01493406]]
# result_deepest_lstm_tinypilotnet -> 6.482017427682877 -0.23967797309160233
# result_lstm_tinypilotnet -> 4.672570824623108 0.5517502799630165
# result_tinypilotnet -> 9.020426332950592 0.6534686721861362
# result_pilotnet -> 9.907716631889343 0.5951058492064476
# ground truth -> [ 0.41176471 -0.06047027]
# result_deepest_lstm_tinypilotnet -> [[ 0.69754326 -0.0274389 ]]
# result_lstm_tinypilotnet -> [[0.33479986 0.02843633]]
# result_tinypilotnet -> [[0.6533514  0.03513462]]
# result_pilotnet -> [[0.79968625 0.01397319]]
# ground truth 2 -> 5.352941176470588 -0.18141080881447746
# ...
